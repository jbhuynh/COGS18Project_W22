# %% [markdown]
# # Project Description

# %% [markdown]
# This is a simple Harry Potter trivia depending on your Hogwarts house. Each person has a chance to win points for their house. If you don't know what your house is no worries as there is an option to answer general questions about the wizarding world. As you answer each question, your current score will be displayed.

# %% [markdown]
# ## Project Code
#
# If it makes sense for your project, you can have code and outputs here in the notebook as well.

# %%
from my_module.functions import hp_intro, house, Gryffindor, Ravenclaw, Hufflepuff, Slytherin, idk_quiz
# Out:
# What is your name?
# audrey
#     Hello audrey! Welcome to Hogwarts! This game
#     will allow you to win points for your house based on how much you know
#     about your Hogwartshouse. Get ready! Each question varies in points
#     depending on level of difficulty. Choose carefully as you can lose
#     points if you answer wrong.
#
# What Hogwarts house are you in? If you don't know, type 'IDK'
#  1. Gryffindor
#  2. Ravenclaw
#  3. Hufflepuff
#  4. Slytherin
#  5. 'IDK'
# 3
#        "Hello sweet badger. I see you are ready to complete this
#         challenge. Proceed with caution. Do not let others get into your head
#         and believe in yourself."
#
# Which house would you like to be tested on?
#  1. Gryffindor
#  2. Ravenclaw
#  3. Hufflepuff
#  4. Slytherin
#  5. 'IDK'
#  3
#
# Good Luck! Answer carefully. Your house is currently at 320 points!
#
# What is Hufflepuff's mascot?
# badger
# Correct! Your score: 325
#
# Who is the resident ghost of Hufflepuff?
# fatfryer
# ...

# %%
# !pytest my_module/test_functions.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.9.5, pytest-6.2.5, py-1.10.0, pluggy-1.0.0
# rootdir: /home/jbhuynh/FinalProject_COGS18_WI22
# plugins: anyio-3.2.1
# collected 0 items / 1 error
#
# ==================================== ERRORS ====================================
# _________________ ERROR collecting my_module/test_functions.py _________________
# my_module/test_functions.py:7: in <module>
#     from functions import hp_intro, house, Gryffindor, Ravenclaw, Hufflepuff, Slytherin, idk_quiz
# my_module/functions.py:391: in <module>
#     hp_intro()
# my_module/functions.py:21: in hp_intro
#     name = input("What is your name?\n")
# /opt/conda/lib/python3.9/site-packages/_pytest/capture.py:217: in read
#     raise OSError(
# E   OSError: pytest: reading from stdin while output is captured!  Consider using `-s`.
# ------------------------------- Captured stdout --------------------------------
# ...

# %% [markdown]
# #### Extra Credit (*optional*)
#
# Replace all of this text with a brief explanation (~3 sentences) of:
# 1. Going into this class, I had no prior python knowledge.
# 2. I challened myself with learning how to properly color and bold the text, rather than copy and pasting and also learned how to embed a video inside of my project which had taken multiple hours as coding is a difficult subject for me to understand. I also learned how to create a quiz style multiple choice. Lastly, I learned how to use sys.exit if someone input an choice not listed.
#
#
# ### Github Link
#
# https://github.com/jbhuynh/COGS18Project_W22

# %% [markdown]
# ###
